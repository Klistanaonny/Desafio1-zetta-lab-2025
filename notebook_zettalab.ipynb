# %% [markdown]
# ## Desafio 1 da segunda edição da zetta LAB 2025
#
# **Nome:** Klistanaonny Amábille Diniz Lucchesi
#
# ---
#
# ### 🎯 Objetivo do projeto
# Este notebook apresenta uma **análise socioeconômica do município de Melgaço (PA)**, com base em dados do **Atlas Brasil (2010)**.
# A investigação aborda as dimensões de **educação, renda e infraestrutura**, com o intuito de compreender os fatores que mais impactam o desenvolvimento humano e econômico no contexto brasileiro.
#
#
#
# ### ❓ Pergunta norteadora
# **Como poderíamos avaliar e prever/visualizar os agentes e fenômenos que mais causam impactos socioeconômicos no Brasil?**
#
#
#
# ### ⚙️ Metodologia
# A análise foi conduzida de forma **comparativa e detalhada**, tomando como referência o município de **Melgaço (PA)** — cidade com o **menor IDH do Brasil** — para evidenciar de maneira clara como os fenômenos sociais e econômicos geram impactos no país de forma geral.
#
# A partir da compreensão de como esses fatores afetam a população e a economia local de Melgaço, ampliou-se a observação para uma **perspectiva macroscópica**, permitindo **identificar padrões** e comparar com outras cidades que apresentam **índices de desenvolvimento humano semelhantes ou contrastantes.**
#
# ### 📥 Aquisição dos dados
# Os dados utilizados neste projeto foram obtidos manualmente a partir do **Atlas Brasil (2010)** e organizados em planilha Excel.
# As informações foram selecionadas com base em indicadores de **educação, renda, infraestrutura e demografia** do município de **Melgaço (PA)**.
# Posteriormente, os dados foram tratados e visualizados em Python, conforme os códigos apresentados nas próximas seções.
#
# ### 🧹 Tratamento e organização dos dados
#
# Os dados utilizados neste projeto foram obtidos manualmente a partir do **Atlas Brasil (2010)** — uma base que integra e padroniza informações do **Censo Demográfico do IBGE**, do **PNUD** e do **IPEA**.
# Embora o Atlas já realize parte do tratamento estatístico e metodológico dos dados originais, foi conduzida uma **curadoria manual** em planilha eletrônica para garantir a consistência das variáveis analisadas.
#
# Durante essa etapa, as informações foram **organizadas, padronizadas e comparadas entre si**, com o objetivo de construir uma base coerente para a exploração visual no Python.
# Foram selecionadas apenas as **variáveis mais relevantes** para o contexto do estudo — **educação, saúde, infraestrutura e demografia** —, removendo colunas com lacunas ou indicadores redundantes.
#
# Esse processo assegura que a análise realizada neste notebook se apoie em dados **confiáveis, consistentes e comparáveis entre os municípios**, refletindo de forma precisa os fenômenos socioeconômicos investigados.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## População
#
# Cerca de 84,37% da população de Melgaço (PA) é composta por pessoas pretas. Esse dado permite compreender como fatores étnico-raciais impactam diretamente o acesso à educação e, consequentemente, o desenvolvimento econômico. O município de Melgaço representa, portanto, um exemplo concreto de como desigualdades históricas podem se refletir nos indicadores socioeconômicos brasileiros.
# A herança da escravidão, que perdurou por séculos no país, deixou marcas profundas na estrutura social brasileira. Mesmo após a abolição da escravidão em 1888, o racismo estrutural continuou limitando as oportunidades de pessoas pretas, que muitas vezes foram excluídas do mercado formal de trabalho e privadas do acesso à educação.
# Essa exclusão histórica gerou ciclos de pobreza: famílias negras, com menor renda e acesso à informação, enfrentam maiores taxas de natalidade e menores condições de escolarização. Assim, é possível perceber que as desigualdades raciais interferem diretamente na educação e, por consequência, no desenvolvimento econômico de municípios como Melgaço.
# Em contextos onde crianças precisam trabalhar para contribuir com a renda familiar, o estudo acaba sendo deixado de lado, o que perpetua a falta de qualificação e
#  mantém baixos os índices de renda. Dessa forma, percebe-se que a questão racial está profundamente interligada à desigualdade educacional e econômica no Brasil.

# %%
# Importando as bibliotecas necessárias
# matplotlib e seaborn para visualização de dados, pandas para manipulação tabular
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Criando um dicionário com os dados de distribuição racial em Melgaço (PA)
# As chaves são os nomes das colunas e os valores são listas com os dados correspondentes
# Dados
dados = {
    "Cor/Raça": ["Pretos", "Pardos", "Brancos", "Outros"],
    "Percentual": [84.37, 10.15, 4.2, 1.28]
}

# Convertendo o dicionário em um DataFrame (estrutura de dados do pandas)
df = pd.DataFrame(dados)


# Definindo o estilo visual do gráfico com o tema "whitegrid" e paleta de cores "viridis"
sns.set(style="whitegrid", palette="viridis")

# Criando a figura e definindo o tamanho
plt.figure(figsize=(8, 5))


# Criando o gráfico de barras com seaborn
# Eixo X: categorias de cor/raça | Eixo Y: percentuais da população
grafico = sns.barplot(
    x="Cor/Raça",
    y="Percentual",
    data=df
)

# Adicionando os valores percentuais acima de cada barra para facilitar a leitura
for i, valor in enumerate(df["Percentual"]):
    plt.text(i, valor + 1, f"{valor:.2f}%", ha="center", fontsize=11, fontweight="bold")

# Adicionando título e rótulos aos eixos
plt.title("Distribuição Racial da População de Melgaço (PA)", fontsize=14, weight="bold")
plt.ylabel("Percentual (%)")
plt.xlabel("")

# Ajustando o limite do eixo Y para dar espaço aos rótulos
plt.ylim(0, 100)

# Ajustando margens e espaçamento do gráfico
plt.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Razão de dependência total

# %% [markdown]
# De acordo com o Atlas Brasil, a razão de dependência total — indicador que representa o número de pessoas dependentes (crianças e idosos) em relação à população em idade ativa (15 a 64 anos) — apresentou queda no município de Melgaço (PA) entre 2000 e 2010, passando de 114,11% para 88,05%.
# Nesse mesmo período, a proporção de idosos diminuiu de 3,01% para 2,61%.
# Essa redução indica que há menos pessoas chegando à velhice, o que pode estar relacionado à baixa expectativa de vida no município. Muitos habitantes precisam começar a trabalhar desde cedo, em atividades de baixa remuneração e alta exigência física, como a pesca e o extrativismo.
# Essa realidade reflete o baixo acesso à educação e à qualificação profissional, o que limita as oportunidades e mantém grande parte da população em condições precárias de trabalho e renda.
# Com o passar dos anos, essa sobrecarga e falta de acesso a serviços de saúde adequados reduzem a qualidade de vida, fazendo com que poucos moradores cheguem à terceira idade. Assim, os dados da razão de dependência total reforçam a conexão entre educação, condições socioeconômicas e longevidade no município de Melgaço.

# %%
# Importando as bibliotecas necessárias
# pandas para manipulação de dados tabulares
# matplotlib e seaborn para visualização de dados
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Criando o DataFrame com os dados da razão de dependência total
# Esse indicador mostra a proporção de pessoas dependentes (crianças e idosos)
# em relação à população em idade ativa (15 a 64 anos)
dados_dependencia = pd.DataFrame({
    "Ano": [2000, 2010],
    "Razão de Dependência Total (%)": [114.11, 88.05]
})

# Criando o DataFrame com os dados da proporção de idosos no município
# Indica a porcentagem de pessoas com 65 anos ou mais em cada ano
dados_idosos = pd.DataFrame({
    "Ano": [2000, 2010],
    "Proporção de Idosos (%)": [3.01, 2.61]
})

# Definindo o estilo visual dos gráficos com seaborn
sns.set(style="whitegrid", palette="crest")

# ==============================
# 📉 Gráfico 1 — Razão de Dependência Total
# ==============================
plt.figure(figsize=(8,5))

# Criando um gráfico de linha para mostrar a variação entre 2000 e 2010
sns.lineplot(
    x="Ano",
    y="Razão de Dependência Total (%)",
    data=dados_dependencia,
    marker="o",
    linewidth=2.5
)

# Título e rótulos dos eixos
plt.title("Queda da Razão de Dependência Total — Melgaço (PA)", fontsize=14, weight="bold")
plt.ylabel("Percentual (%)")
plt.xlabel("Ano")

# Definindo os limites do eixo Y para melhorar a visualização
plt.ylim(80, 120)

# Adicionando os valores percentuais acima dos pontos
for i, v in enumerate(dados_dependencia["Razão de Dependência Total (%)"]):
    plt.text(dados_dependencia["Ano"][i], v + 1, f"{v:.2f}%", ha='center', fontsize=11, fontweight="bold")

# Ajustando margens e exibindo o gráfico
plt.tight_layout()
plt.show()

# ==============================
# 👵 Gráfico 2 — Proporção de Idosos
# ==============================
plt.figure(figsize=(6,5))

# Criando um gráfico de barras para comparar a proporção de idosos nos dois anos
sns.barplot(
    x="Ano",
    y="Proporção de Idosos (%)",
    data=dados_idosos,
    palette="crest"
)

# Título e rótulos dos eixos
plt.title("Proporção de Idosos — Melgaço (PA)", fontsize=14, weight="bold")
plt.ylabel("Percentual (%)")
plt.ylim(0, 4)
for i, v in enumerate(dados_idosos["Proporção de Idosos (%)"]):
    plt.text(i, v + 0.1, f"{v:.2f}%", ha='center', fontsize=11, fontweight="bold")

# Ajustando margens e exibindo o gráfico
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_15509/1199161637.py:62: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# O gráfico mostra uma queda significativa tanto na razão de dependência total quanto na proporção de idosos, o que reforça a baixa expectativa de vida e a precariedade das condições de trabalho e saúde em Melgaço.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Pirâmide etária

# %% [markdown]
# Ao observar a pirâmide etária de Melgaço (PA) disponível no Atlas Brasil, nota-se uma base larga que se estreita rapidamente ao longo da estrutura. Isso indica que o município possui alta taxa de natalidade e uma população predominantemente jovem.
# Uma das principais causas desse padrão pode estar relacionada à gravidez na adolescência. Muitos jovens carecem de acesso à informação sobre sexualidade, métodos contraceptivos e prevenção de infecções sexualmente transmissíveis.
# A falta desse conhecimento básico leva a gestações precoces, e, diante da necessidade de sustento, muitas dessas jovens mães e pais abandonam os estudos para trabalhar. Esse cenário reduz a qualificação profissional e perpetua o ciclo de pobreza na região.
# Além disso, parte da população não tem clareza sobre as consequências socioeconômicas de uma gravidez precoce, tanto para a família quanto para o município. O aumento do número de filhos em contextos de vulnerabilidade tende a sobrecarregar a renda familiar, dificultar o acesso a serviços básicos e impactar negativamente o desenvolvimento econômico local.
# Dessa forma, a pirâmide etária de Melgaço reflete não apenas um fenômeno demográfico, mas também as desigualdades educacionais e informacionais que afetam diretamente o futuro de sua população.

# %%
# Importando as bibliotecas necessárias
# pandas: manipulação e organização de dados
# matplotlib e seaborn: criação e personalização dos gráficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Criando listas com as faixas etárias e os percentuais de homens e mulheres
# Esses valores são simulados para representar o formato da pirâmide etária de Melgaço (PA)
faixas = ["0–4", "5–9", "10–14", "15–19", "20–24", "25–29", "30–39", "40–49", "50–59", "60+"]
homens = [8, 7.5, 7, 6.5, 6, 5.5, 4, 3, 2, 1]
mulheres = [7.5, 7, 6.8, 6.2, 6, 5.7, 4.2, 3.2, 2.2, 1.2]

# Criando um DataFrame com os dados simulados
# Cada linha representa uma faixa etária e as colunas indicam o percentual de homens e mulheres
df = pd.DataFrame({
    "Faixa Etária": faixas,
    "Homens": homens,
    "Mulheres": mulheres
})

# Definindo o estilo visual do gráfico
sns.set(style="whitegrid")

# Criando a figura e ajustando o tamanho
plt.figure(figsize=(8,6))

# Criando as barras horizontais da pirâmide etária
# As barras dos homens são negativas para que apareçam à esquerda
plt.barh(df["Faixa Etária"], -df["Homens"], color="#4C72B0", label="Homens")
# As barras das mulheres são positivas (à direita)
plt.barh(df["Faixa Etária"], df["Mulheres"], color="#DD8452", label="Mulheres")

# Adicionando título e rótulos dos eixos
plt.title("Pirâmide Etária de Melgaço (PA) — Representação", fontsize=14, weight="bold")
plt.xlabel("Percentual da População (%)")
plt.ylabel("Faixa Etária")

# Ajustando o eixo X para mostrar valores absolutos simétricos dos dois lados
plt.xlim(-10, 10)
plt.xticks(range(-10, 11, 2), [abs(x) for x in range(-10, 11, 2)])

# Adicionando legenda para diferenciar homens e mulheres
plt.legend(loc="lower right")

# Ajustando margens e espaçamento
plt.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# O formato da pirâmide — com base larga e topo estreito — indica que poucos habitantes chegam à velhice, reflexo da baixa qualidade de vida, da desigualdade e do trabalho precoce.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Mortalidade infantil

# %% [markdown]
# A mortalidade infantil representa o número de crianças que morrem antes de completar um ano de idade, em relação ao total de nascidos vivos em determinado período.
# De acordo com o Atlas Brasil, o índice de Melgaço (PA) apresentou redução significativa entre 2000 e 2010 — passando de 45,39 para 22,40 mortes por mil nascidos vivos.
# Apesar dessa melhora, o valor ainda está acima da meta estabelecida pela ONU, que prevê menos de 12 mortes por mil até 2030.
# Esse indicador continua sendo motivo de preocupação no município e pode ser explicado, em parte, pelas condições socioeconômicas e educacionais da população.
# A falta de informação sobre saúde e planejamento familiar faz com que muitas gestações ocorram sem acompanhamento médico adequado, e a ausência de pré-natal aumenta os riscos durante e após o parto.
# Além disso, grande parte das famílias não possui renda suficiente para garantir cuidados básicos nos primeiros meses de vida do bebê, como a realização do teste do pezinho, essencial para detectar precocemente doenças genéticas e metabólicas.
# Assim, observa-se que a mortalidade infantil em Melgaço está fortemente ligada à desigualdade social, à desinformação e à precariedade dos serviços de saúde, perpetuando o ciclo de vulnerabilidade do município.

# %%
# Importando as bibliotecas necessárias
# pandas: manipulação e organização dos dados
# matplotlib e seaborn: criação e personalização dos gráficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Criando um DataFrame com os dados de mortalidade infantil de Melgaço (PA)
# O indicador representa o número de crianças que morrem antes de completar um ano de idade
# a cada mil nascidos vivos
dados = pd.DataFrame({
    "Ano": [2000, 2010],
    "Mortalidade Infantil (por mil nascidos vivos)": [45.39, 22.40]
})

# Definindo o estilo visual do gráfico
sns.set(style="whitegrid", palette="crest")

# Criando a figura e ajustando o tamanho
plt.figure(figsize=(8,5))

# Criando a linha principal que mostra a evolução da mortalidade infantil entre 2000 e 2010
sns.lineplot(
    data=dados,
    x="Ano",
    y="Mortalidade Infantil (por mil nascidos vivos)",
    marker="o",          # adiciona marcadores nos pontos
    linewidth=2.5,       # espessura da linha
    color="#2E86AB",     # cor personalizada
    label="Melgaço (PA)" # legenda da linha principal
)

# Adicionando uma linha de referência com a meta estabelecida pela ONU (12 mortes por mil)
# Essa linha serve para comparar o desempenho de Melgaço com o objetivo global até 2030
plt.axhline(12, color="#E74C3C", linestyle="--", linewidth=2, label="Meta da ONU (2030)")

# Definindo o título e os rótulos dos eixos
plt.title("Redução da Mortalidade Infantil — Melgaço (PA)", fontsize=14, weight="bold")
plt.ylabel("Mortes por mil nascidos vivos")
plt.xlabel("Ano")

# Definindo os limites do eixo Y para melhor visualização
plt.ylim(0, 50)

# Adicionando os valores numéricos sobre os pontos do gráfico
for i, v in enumerate(dados["Mortalidade Infantil (por mil nascidos vivos)"]):
    plt.text(dados["Ano"][i], v + 1, f"{v:.2f}", ha='center', fontsize=11, fontweight="bold")

# Exibindo a legenda, ajustando o layout e mostrando o gráfico
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Apesar da melhora, o valor ainda é quase o dobro da meta da ONU para 2030 (12 mortes por mil).
# Essa diferença reflete as dificuldades de acesso à saúde, educação e renda — fatores que perpetuam a vulnerabilidade social no município.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Fluxo escolar de crianças e jovens

# %% [markdown]
# De acordo com os dados do Atlas Brasil, em Melgaço (PA), 58,68% das crianças de 5 a 6 anos estão na escola, enquanto apenas 35,83% das crianças de 11 a 13 anos frequentam os anos finais do ensino fundamental. Entre os jovens de 15 a 17 anos, apenas 6,89% concluíram o ensino fundamental, e, entre os jovens de 18 a 20 anos, 5,63% completaram o ensino médio.
# Esses números evidenciam que, conforme a idade aumenta, a permanência escolar diminui de forma acentuada. Tal fenômeno está diretamente ligado a fatores econômicos e sociais já discutidos nas seções anteriores, como a necessidade de trabalhar desde cedo para contribuir com a renda familiar.
# A elevada porcentagem de crianças matriculadas entre 5 e 6 anos pode estar associada ao fato de que muitos pais utilizam a escola como um espaço seguro enquanto trabalham, o que permite maior disponibilidade de tempo para atividades laborais. Entretanto, à medida que essas crianças crescem, a pressão econômica e a falta de oportunidades educacionais adequadas levam ao abandono escolar, reforçando o ciclo de pobreza e baixa qualificação no município.
# Portanto, o fluxo escolar em Melgaço reflete a vulnerabilidade social das famílias, o trabalho precoce e as limitações estruturais do sistema educacional, que impedem a continuidade dos estudos e comprometem o desenvolvimento humano local.

# %%
# Importando as bibliotecas necessárias
# pandas: para manipulação e estruturação dos dados
# matplotlib e seaborn: para criação e personalização dos gráficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Criando o DataFrame com as informações sobre a escolarização por faixa etária
# Cada valor representa o percentual de crianças e jovens de Melgaço (PA) que frequentam a escola
dados = pd.DataFrame({
    "Faixa Etária": ["5–6 anos", "11–13 anos", "15–17 anos", "18–20 anos"],
    "Percentual na escola (%)": [58.68, 35.83, 6.89, 5.63]
})

# Definindo o estilo visual do gráfico
sns.set(style="whitegrid", palette="crest")

# Criando a figura e ajustando o tamanho
plt.figure(figsize=(8,5))

# Criando o gráfico de linha para representar o fluxo escolar
# A linha mostra como o percentual de alunos matriculados diminui conforme a idade aumenta
sns.lineplot(
    data=dados,
    x="Faixa Etária",
    y="Percentual na escola (%)",
    marker="o",       # adiciona marcadores nos pontos
    linewidth=2.5,    # define a espessura da linha
    color="#2E86AB"   # define a cor da linha
)

# Adicionando os valores percentuais acima de cada ponto para facilitar a leitura
for i, v in enumerate(dados["Percentual na escola (%)"]):
    plt.text(i, v + 2, f"{v:.2f}%", ha='center', fontsize=11, fontweight="bold")

# Adicionando título e rótulos dos eixos
plt.title("Fluxo Escolar em Melgaço (PA)", fontsize=14, weight="bold")
plt.ylabel("Percentual de estudantes (%)")
plt.xlabel("Faixa Etária")

# Definindo o limite do eixo Y para melhorar a visualização
plt.ylim(0, 65)

# Ajustando margens e espaçamento
plt.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# O gráfico ilustra como fatores econômicos e sociais — como o trabalho precoce e a falta de oportunidades — levam ao abandono escolar.
# Esse padrão reforça o ciclo de vulnerabilidade e limita o desenvolvimento humano local.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Defasagem e Evasão em Melgaço

# %% [markdown]
# Em 2010, 57,25% das crianças e jovens de 6 a 17 anos em Melgaço (PA) apresentavam até dois anos de atraso escolar — uma melhora em relação a 2000, quando o índice era de 64,58%.
# No ensino médio, a distorção idade-série (alunos com idade acima da esperada para o ano cursado) atingia 67,70% em 2017, mostrando uma leve redução em relação a 2016 (70,6%).
# Já a evasão escolar no ensino fundamental foi de 6,40% em 2014, ligeiramente superior ao valor de 2013 (6%). No ensino médio, o índice caiu de 20,20% (2013) para 16,40% (2014).
# Apesar dessas variações, observa-se uma relativa constância nos indicadores, revelando que os desafios da educação em Melgaço permanecem estruturais. A defasagem, a distorção e a evasão estão intimamente relacionadas e refletem as dificuldades sociais do município.
# Muitos responsáveis, especialmente jovens pais e mães, enfrentam falta de acesso à informação e à orientação sobre os direitos e deveres educacionais. Questões básicas, como o registro civil das crianças, matrícula escolar e acompanhamento pedagógico, muitas vezes não são plenamente compreendidas ou realizadas — seja pela desinformação, seja pela falta de tempo, uma vez que muitas famílias precisam escolher entre trabalhar ou passar fome.
# Outro fator importante a ser considerado é o desinteresse crescente dos jovens pela escola. Diante de uma realidade em que o trabalho representa um retorno financeiro imediato, muitos optam por ingressar cedo no mercado informal, em vez de investir em estudos cujo retorno é de longo prazo.
# Essa percepção faz com que a escola pareça pouco atrativa, e a repetência se torne mais comum. Consequentemente, o número de alunos com idade acima da esperada para a série aumenta, reforçando o desequilíbrio apontado pelos dados de distorção idade-série.
# Assim, a evasão escolar em Melgaço não se limita à falta de estrutura ou renda, mas também reflete a perda de significado da educação para parte da juventude, que enxerga o trabalho imediato como a única alternativa de sobrevivência.
# Esse ciclo mantém os jovens em empregos precários e mal remunerados, impedindo a ascensão social e perpetuando a desigualdade educacional e econômica no município.

# %%
# Importando as bibliotecas necessárias
# pandas: para criar e manipular os DataFrames com os dados
# matplotlib e seaborn: para criação e personalização dos gráficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definindo o estilo visual dos gráficos
sns.set(style="whitegrid", palette="crest")

# ==============================================================
# 1️⃣ Atraso Escolar — Percentual de alunos com até dois anos de defasagem
# ==============================================================

# Criando o DataFrame com os dados de atraso escolar
atraso = pd.DataFrame({
    "Ano": [2000, 2010],
    "Atraso Escolar (%)": [64.58, 57.25]
})

# Criando o gráfico de linha para representar a evolução do atraso escolar
plt.figure(figsize=(7,4))
sns.lineplot(data=atraso, x="Ano", y="Atraso Escolar (%)", marker="o", color="#2E86AB")

# Adicionando título e valores sobre os pontos
plt.title("Atraso Escolar — Melgaço (PA)", fontsize=13, weight="bold")
for i, v in enumerate(atraso["Atraso Escolar (%)"]):
    plt.text(atraso["Ano"][i], v + 1, f"{v:.2f}%", ha='center', fontsize=10, fontweight="bold")

# Ajustando os limites do eixo Y e exibindo o gráfico
plt.ylim(50, 70)
plt.tight_layout()
plt.show()


# ==============================================================
# 2️⃣ Distorção Idade-Série — Percentual de alunos fora da faixa etária ideal
# ==============================================================

# Criando o DataFrame com os dados de distorção idade-série (ensino médio)
distorcao = pd.DataFrame({
    "Ano": [2016, 2017],
    "Distorção Idade-Série (%)": [70.6, 67.7]
})

# Criando o gráfico de linha para representar a variação entre os anos
plt.figure(figsize=(7,4))
sns.lineplot(data=distorcao, x="Ano", y="Distorção Idade-Série (%)", marker="o", color="#A569BD")

# Adicionando título e valores acima dos pontos
plt.title("Distorção Idade-Série (Ensino Médio) — Melgaço (PA)", fontsize=13, weight="bold")
for i, v in enumerate(distorcao["Distorção Idade-Série (%)"]):
    plt.text(distorcao["Ano"][i], v + 1, f"{v:.1f}%", ha='center', fontsize=10, fontweight="bold")

# Ajustando limites e layout
plt.ylim(65, 75)
plt.tight_layout()
plt.show()


# ==============================================================
# 3️⃣ Evasão Escolar — Percentual de alunos que abandonaram os estudos
# ==============================================================

# Criando o DataFrame com dados de evasão no ensino fundamental e médio
evasao = pd.DataFrame({
    "Ano": ["2013 (Fund.)", "2014 (Fund.)", "2013 (Médio)", "2014 (Médio)"],
    "Evasão Escolar (%)": [6.0, 6.4, 20.2, 16.4]
})

# Criando o gráfico de barras para comparar os valores de evasão
plt.figure(figsize=(8,5))
sns.barplot(data=evasao, x="Ano", y="Evasão Escolar (%)", hue="Ano", palette="crest")

# Adicionando título e rótulos
plt.title("Evasão Escolar — Melgaço (PA)", fontsize=13, weight="bold")

# Adicionando os valores numéricos acima das barras
for i, v in enumerate(evasao["Evasão Escolar (%)"]):
    plt.text(i, v + 0.5, f"{v:.1f}%", ha='center', fontsize=10, fontweight="bold")

# Ajustando limites do eixo Y e removendo a legenda duplicada
plt.ylim(0, 25)
plt.legend([],[], frameon=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# Os dados mostram que, embora haja pequenas reduções nos índices, o problema da permanência escolar continua estrutural.
# A pressão econômica e o desinteresse pela escola reforçam o ciclo de exclusão educacional e social em Melgaço.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Expectativa de anos de estudo

# %% [markdown]
# Entre 2000 e 2010, as crianças de Melgaço (PA) passaram a permanecer mais tempo na escola. O indicador de expectativa de anos de estudo aumentou de 2,82 para 5,51 anos, um crescimento considerável de 2,69 anos em uma década.
# Apesar dessa melhora, a média ainda está bem abaixo da registrada no estado do Pará (8,49 anos), o que revela que o avanço, embora relevante, não foi suficiente para equiparar Melgaço às demais regiões do estado.
# Essa elevação pode estar relacionada a mudanças estruturais e econômicas ocorridas no período, como a criação e expansão de programas sociais (a exemplo do Bolsa Família), o incentivo à permanência escolar por meio de campanhas públicas, o investimento em transporte estudantil e a construção de novas unidades escolares.
# Tais políticas podem ter contribuído para reduzir barreiras de acesso à educação, resultando na melhora observada no indicador.
# É importante destacar que a educação e a economia se influenciam mutuamente, compondo um ciclo interdependente. O fortalecimento econômico pode ampliar o investimento em políticas públicas e, consequentemente, melhorar a qualidade e a permanência escolar. Por outro lado, o avanço educacional contribui para o desenvolvimento econômico, ao formar cidadãos mais qualificados e conscientes de seus direitos.
# Entretanto, caso essa melhora não se mantenha de forma progressiva nos anos seguintes, é provável que problemas estruturais persistam, como o trabalho infantil e a necessidade econômica das famílias, que ainda obrigam crianças e adolescentes a abandonar os estudos precocemente.
# Essa situação, além de comprometer o desenvolvimento humano local, viola a Constituição Federal, que garante o direito e o dever da criança e do adolescente de permanecer na escola até, no mínimo, os 17 anos de idade (Art. 208, inciso I).
# Portanto, a expectativa de anos de estudo em Melgaço reflete tanto os avanços obtidos com políticas públicas quanto os desafios persistentes da desigualdade socioeconômica, que ainda impedem a concretização plena do direito à educação.

# %% [markdown]
# A comparação evidencia o impacto positivo das políticas públicas, mas também reforça que a desigualdade educacional ainda é profunda.
# O aumento, embora expressivo, não garante equidade de oportunidades nem o cumprimento pleno do direito à educação previsto na Constituição.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Escolarização da população adulta

# %% [markdown]
# Ao analisar os dados sobre a escolarização da população adulta em Melgaço (PA), observa-se que 47,26% dos habitantes possuem apenas o ensino fundamental incompleto ou são analfabetos, enquanto apenas 2,04% concluíram o ensino superior.
# Esses números revelam um cenário preocupante não apenas no campo educacional, mas também no campo político e econômico.
# Indivíduos com menor acesso à educação formal tendem a enfrentar maiores dificuldades em compreender informações complexas, especialmente no ambiente político atual, marcado pela disseminação de fake news.
# A escola é o espaço em que se aprende a questionar, interpretar e pensar criticamente — sem esse aprendizado, torna-se muito mais difícil distinguir o verdadeiro do falso, o justo do manipulador.
# Quando grande parte da população não tem tempo para estudar, pois dedica suas horas à luta pela sobrevivência econômica, o resultado é uma sociedade em que o pensamento crítico é sufocado pelo cansaço e pela desinformação.
# Essa falta de conscientização pode influenciar diretamente nas decisões políticas, como o voto, afetando a escolha de representantes e, consequentemente, o rumo econômico do país.
# O conhecimento é, portanto, a ferramenta mais poderosa de transformação social.
# Com informação e consciência, é possível ir longe — mesmo quando faltam caminhos abertos diante dos pés.

# %%
# Importando as bibliotecas necessárias
# pandas: manipulação de dados
# matplotlib e seaborn: criação e personalização dos gráficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Criando um DataFrame com os dados sobre o nível de escolaridade da população adulta
# Cada categoria representa um nível de instrução e seu respectivo percentual em Melgaço (PA)
dados = pd.DataFrame({
    "Nível de Escolaridade": [
        "Fundamental incompleto ou analfabetos",
        "Fundamental completo",
        "Ensino médio completo",
        "Ensino superior completo"
    ],
    "Percentual da População (%)": [47.26, 20.0, 15.0, 2.04]
})

# Definindo o estilo do gráfico (fundo branco com linhas suaves e paleta agradável)
sns.set(style="whitegrid", palette="crest")

# Criando a figura e ajustando o tamanho
plt.figure(figsize=(9,5))

# Gráfico de barras horizontais, ideal para comparar categorias textuais
sns.barplot(
    data=dados,
    y="Nível de Escolaridade",
    x="Percentual da População (%)",
    palette="viridis"  # cores em gradiente de verde/azul para destacar os níveis
)

# Adicionando os valores percentuais no final de cada barra
for i, v in enumerate(dados["Percentual da População (%)"]):
    plt.text(v + 0.8, i, f"{v:.2f}%", va='center', fontsize=11, fontweight="bold")

# Adicionando título e rótulos dos eixos
plt.title("Escolarização da População Adulta — Melgaço (PA)", fontsize=14, weight="bold")
plt.xlabel("Percentual da População (%)")
plt.ylabel("")

# Definindo o limite do eixo X para deixar espaço pros textos
plt.xlim(0, 55)

# Ajustando margens e layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()
# Out:
# /tmp/ipykernel_15509/2008548714.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# O baixo nível de escolarização limita o acesso à informação e reduz a capacidade crítica da população, afetando o desenvolvimento econômico e a participação cidadã.
# O conhecimento, portanto, é o instrumento mais poderoso de transformação social.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Habitação e vulnerabilidade

# %% [markdown]
# Em Melgaço (PA), apenas 67,66% da população possui acesso à água encanada.
# Embora esse número possa parecer razoável diante do contexto socioeconômico do município, ele revela que mais de um terço dos habitantes ainda vive sem um recurso essencial à saúde e à dignidade humana.
# A falta de saneamento adequado aumenta a exposição a doenças infecciosas e parasitárias, comprometendo a qualidade de vida e sobrecarregando os serviços públicos de saúde.
# De acordo com um documentário produzido pela BBC News, é possível observar fisicamente que nenhuma residência do município possui tratamento de esgoto, o que evidencia de forma concreta a gravidade da situação sanitária em Melgaço.
# A ausência completa desse serviço básico expõe a população a um enorme risco biológico e demonstra o quanto a infraestrutura local está distante dos padrões mínimos de qualidade de vida.
# Essa realidade contrasta fortemente com a de São Caetano do Sul (SP), cidade com o maior IDH do Brasil, onde 100% da população possui acesso à água tratada e encanada (dados de aguaesaneamento.org).
# A comparação evidencia como o acesso à infraestrutura básica é um marcador direto da desigualdade social e econômica no país.
# Entende-se, portanto, que vulnerabilidade social não se limita à ausência de renda, mas à exposição constante a condições precárias de moradia, saúde e educação.
# Populações vulneráveis, como a de Melgaço, estão mais sujeitas a problemas de saúde, evasão escolar e exclusão social, o que perpetua um ciclo de pobreza difícil de romper. Dessa forma, a análise do acesso à água encanada, ao esgoto e à habitação adequada reforça que as desigualdades estruturais do Brasil vão além da economia, alcançando dimensões básicas da sobrevivência humana e comprometendo o desenvolvimento social e econômico a longo prazo.

# %%
# Importando as bibliotecas necessárias
# pandas: para manipulação de dados em formato de tabela
# matplotlib e seaborn: para criação e customização de gráficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Criando um DataFrame com os dados sobre acesso à água e esgoto em duas cidades
# Os dados evidenciam a diferença de infraestrutura entre Melgaço (PA) e São Caetano do Sul (SP)
dados = pd.DataFrame({
    "Cidade": ["Melgaço (PA)", "Melgaço (PA)", "São Caetano do Sul (SP)", "São Caetano do Sul (SP)"],
    "Indicador": ["Água encanada", "Esgoto tratado", "Água encanada", "Esgoto tratado"],
    "Percentual (%)": [67.66, 0, 100, 100]
})

# Definindo o estilo visual do gráfico
sns.set(style="whitegrid", palette="crest")

# Criando a figura e ajustando o tamanho
plt.figure(figsize=(9,5))

# Criando um gráfico de barras agrupadas para comparar os dois indicadores em cada cidade
sns.barplot(
    data=dados,
    x="Cidade",
    y="Percentual (%)",
    hue="Indicador",                # separa as barras por tipo de infraestrutura
    palette=["#2E86AB", "#85C1E9"]  # tons diferentes para água e esgoto
)

# Adicionando os valores percentuais acima de cada barra
# O cálculo da posição (i//2 e ±0.18) centraliza os textos sobre as barras correspondentes
for i, v in enumerate(dados["Percentual (%)"]):
    plt.text(i//2 + (0.18 if i % 2 == 0 else -0.18), v + 2, f"{v:.0f}%", 
             ha='center', fontsize=11, fontweight="bold")

# Adicionando título e rótulos dos eixos
plt.title("Acesso à Infraestrutura Básica — Melgaço (PA) vs São Caetano do Sul (SP)", 
          fontsize=14, weight="bold")
plt.ylabel("Percentual da População (%)")

# Definindo limite do eixo Y para deixar espaço para os rótulos
plt.ylim(0, 110)

# Exibindo a legenda e organizando o layout final
plt.legend(title="Indicador")
plt.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Essa diferença mostra como o saneamento é um marcador direto da desigualdade social e econômica.
# A ausência de infraestrutura básica agrava os problemas de saúde e educação, perpetuando o ciclo de vulnerabilidade.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Extra (opcional) de resolução dos problemas apresentados
#
#
# A transformação social de cidades com baixos índices de desenvolvimento humano, como Melgaço, exige ações contínuas, planejadas e interligadas entre educação, economia, saúde e infraestrutura. Não existe uma solução única, mas um conjunto de medidas que, implementadas de forma gradual e integrada, podem alterar o futuro dessas regiões.
# O ponto de partida deve ser o fortalecimento da educação básica, tanto em estrutura quanto em permanência escolar.
# Em Melgaço, segundo documentário produzido pela BBC News, muitas crianças não conseguem concluir o ensino médio por falta de escolas próximas que ofereçam essa etapa de ensino.
# As poucas escolas existentes sofrem com ausência de professores, falta de água encanada e carência alimentar, o que torna o ambiente escolar precário e pouco atrativo.
# Nesse contexto, é fundamental que os órgãos públicos se mobilizem para garantir infraestrutura, transporte, alimentação escolar e formação docente de qualidade, assegurando que a educação deixe de ser um privilégio e se torne um direito efetivo.
#
# Caso o poder público não consiga suprir essas lacunas de forma eficiente, ações coletivas e projetos públicos de iniciativa popular podem atuar como forças transformadoras.
# Iniciativas como mobilizações de professores voluntários, campanhas em redes sociais e projetos de extensão universitária voltados à educação de base podem levar conhecimento e oportunidades às regiões mais isoladas, fortalecendo a consciência social e a cidadania.
# No campo econômico, é necessário estimular a economia local por meio de programas de microcrédito e capacitação profissional, voltados principalmente a jovens e mulheres.
# Cidades com pouca diversificação produtiva, como Melgaço, dependem quase exclusivamente de atividades como pesca e agricultura de subsistência — setores que precisam ser modernizados e sustentáveis, de modo a gerar renda sem comprometer o meio ambiente.
# A criação de cooperativas comunitárias, iniciativas de empreendedorismo social e incentivos à economia solidária são caminhos concretos para fortalecer a renda local.
# Na saúde e infraestrutura, o investimento em saneamento básico universal, acesso à água potável e infraestrutura urbana mínima é urgente. Além de reduzir doenças, essas melhorias impactam diretamente o desempenho escolar e o desenvolvimento econômico, pois uma população saudável é mais produtiva e ativa socialmente.
# Políticas públicas de longo prazo devem prever metas progressivas, fiscalizadas com transparência e governança de dados, para garantir que cada etapa de avanço seja mensurada e corrigida quando necessário.
#
# Por fim, é essencial fortalecer o acesso à informação e à consciência cidadã.
# A educação política e digital — ensinando desde cedo a identificar informações falsas, compreender direitos e participar das decisões coletivas — é o que permite que o cidadão deixe de ser apenas um espectador da desigualdade e passe a atuar como agente de transformação.
# Em síntese, o desenvolvimento de municípios com baixo IDH depende de ações integradas, persistentes e monitoradas por indicadores reais, como os próprios dados que embasaram este estudo.
# Com o tempo, é possível transformar a vulnerabilidade em potencial humano — desde que tanto o poder público quanto a sociedade civil assumam juntos a responsabilidade de reconstruir o futuro, unindo dados, educação e empatia como instrumentos de mudança.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Cidades com Índice de Desenvolvimento Humano (IDH) semelhante ao de Melgaço (PA) tendem a enfrentar desafios sociais e econômicos muito parecidos, revelando um padrão entre municípios de baixo desenvolvimento.
# Esses locais compartilham problemas relacionados à qualidade de vida, condições de saúde, baixa escolaridade e precariedade no mercado de trabalho — fatores que afetam diretamente o desenvolvimento humano e comprometem o bem-estar da população, refletindo no crescimento econômico local.
# Por outro lado, cidades com IDH mais elevado geralmente apresentam melhores indicadores educacionais, maior formalização no emprego, infraestrutura consolidada e serviços públicos mais eficientes.
#
# Essa diferença reforça a forte correlação entre níveis de desenvolvimento humano e as condições socioeconômicas regionais observadas no Brasil.
# De acordo com o site O Globo, cidades com os piores IDHs do país apresentam padrões semelhantes de vulnerabilidade.
# O IDH de Melgaço é de 0,418, enquanto o de Fernando Falcão (MA) é de 0,443, e ambas possuem pirâmides etárias com base larga e topo estreito, o que indica alta taxa de natalidade e baixo envelhecimento populacional.
#
# Esses fatores estão diretamente relacionados à gravidez precoce, falta de planejamento familiar, desinformação sobre prevenção sexual e baixo nível de escolaridade — elementos que, por sua vez, estão ligados à renda e à desigualdade social. Enquanto Melgaço (PA) apresenta um IDH de 0,418, São Caetano do Sul (SP), o maior do país, possui IDH de 0,862 (Atlas Brasil, 2010), o que evidencia o abismo entre as realidades sociais brasileiras.
# Assim, ao analisar em profundidade os fenômenos de uma cidade onde os problemas sociais são tão evidentes, torna-se possível compreender como cada aspecto — educação, saúde, habitação e renda — se conecta em um ciclo contínuo que influencia toda a economia local.
#
# Ao ampliar essa análise, percebe-se que esses mesmos problemas se repetem em municípios semelhantes e, embora em menor escala, também estão presentes em cidades de alto desenvolvimento, mostrando que a desigualdade brasileira é estrutural e multifacetada. Dessa forma, compreender os dados de Melgaço é compreender um retrato ampliado do Brasil: um país onde o progresso ainda convive com a exclusão, e onde o investimento em educação, infraestrutura e políticas públicas sustentáveis é o caminho mais concreto para quebrar o ciclo de vulnerabilidade e promover o verdadeiro desenvolvimento humano.
